# %% [markdown]
# <a href="https://colab.research.google.com/github/Delusional-bishop/EDSM-laboratory/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv("health care diabetes.csv")

# %%
# Display all column names
print("Columns in the dataset:")
print(df.columns)
# Out:
# Columns in the dataset:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# Display each column individually (optional)
for column in df.columns:
    print(f"\nColumn: {column}")
    print(df[column].head())
# Out:
# Column: Pregnancies
# 0    6
# 1    1
# 2    8
# 3    1
# 4    0
# Name: Pregnancies, dtype: int64
#
# Column: Glucose
# 0    148
# 1     85
# 2    183
# 3     89
# 4    137
# Name: Glucose, dtype: int64
#
# Column: BloodPressure
# 0    72
# 1    66
# 2    64
# 3    66
# 4    40
# Name: BloodPressure, dtype: int64
#
# Column: SkinThickness
# 0    35
# 1    29
# 2     0
# 3    23
# 4    35
# Name: SkinThickness, dtype: int64
#
# Column: Insulin
# 0      0
# 1      0
# 2      0
# 3     94
# 4    168
# Name: Insulin, dtype: int64
#
# Column: BMI
# 0    33.6
# 1    26.6
# 2    23.3
# 3    28.1
# 4    43.1
# Name: BMI, dtype: float64
#
# Column: DiabetesPedigreeFunction
# 0    0.627
# 1    0.351
# 2    0.672
# 3    0.167
# 4    2.288
# Name: DiabetesPedigreeFunction, dtype: float64
#
# Column: Age
# 0    50
# 1    31
# 2    32
# 3    21
# 4    33
# Name: Age, dtype: int64
#
# Column: Outcome
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
# Calculate and display mean, median, and mode for each column
print("\n--- Statistical Summary ---")
for column in df.select_dtypes(include=['number']).columns:
    print(f"\n{column}:")
    print(f"Mean: {df[column].mean()}")
    print(f"Median: {df[column].median()}")
    print(f"Mode: {df[column].mode().values}")
# Out:
# --- Statistical Summary ---
#
# Pregnancies:
# Mean: 3.8450520833333335
# Median: 3.0
# Mode: [1]
#
# Glucose:
# Mean: 120.89453125
# Median: 117.0
# Mode: [ 99 100]
#
# BloodPressure:
# Mean: 69.10546875
# Median: 72.0
# Mode: [70]
#
# SkinThickness:
# Mean: 20.536458333333332
# Median: 23.0
# Mode: [0]
#
# Insulin:
# Mean: 79.79947916666667
# Median: 30.5
# Mode: [0]
#
# BMI:
# Mean: 31.992578124999998
# Median: 32.0
# Mode: [32.]
#
# DiabetesPedigreeFunction:
# Mean: 0.47187630208333325
# Median: 0.3725
# Mode: [0.254 0.258]
#
# Age:
# Mean: 33.240885416666664
# Median: 29.0
# Mode: [22]
#
# Outcome:
# Mean: 0.3489583333333333
# Median: 0.0
# Mode: [0]

# %%
# Correlation matrix
correlation_matrix = df.corr()

print("\n--- Correlation Coefficients ---")
print(correlation_matrix)
# Out:
# --- Correlation Coefficients ---
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
# Heatmap of correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
